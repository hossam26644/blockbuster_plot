# %%
pop_recent = 100000
pop_ancient = 1000000
time_point = 10000

# %%
theata_recent = 2 * pop_recent
time_ne = time_point/pop_recent
relative_size = pop_ancient/pop_recent

# !.././bin/blockbuster_simulator -n 20 -t {theata_recent} -p {time_ne},{relative_size} -o example_sfs.blk -f 1 -e 0
# Out:
# n_samples: 20
# theta: 200000.000000
# oriented: 1
# seed: -1
# outfile: example_sfs.blk
# noised: 0
# parameters: 0.100000 10.000000
# Temps d'exécution : 0.0002470000 secondes

# %%
pop_recent = 544200
pop_1 = 145300
pop_2 = 652700
time_point_1 = 220000
time_point_2 = 2200000

# %%
theata_recent = 2 * pop_recent
time_ne_1 = time_point_1/pop_recent
time_ne_2 = time_point_2/pop_recent
relative_size_1 = pop_1/pop_recent
relative_size_2 = pop_2/pop_recent

# !.././bin/blockbuster_simulator -n 20 -t {theata_recent} -p {time_ne_1},{time_ne_2},{relative_size_1},{relative_size_2} -o example_sfs.blk -f 1 -e 0
# Out:
# n_samples: 20
# theta: 1088400.000000
# oriented: 1
# seed: -1
# outfile: example_sfs.blk
# noised: 0
# parameters: 0.404263 4.042631 0.266997 1.199375
# Temps d'exécution : 0.0005420000 secondes

# %% [markdown]
#   - {end_time: 200000, start_size: 1720600.0}
#   - {end_time: 158000, start_size: 8603000.0}
#   - {end_time: 154600, start_size: 2200}
#   - {end_time: 0, start_size: 1075000.0}

# %%
pop_recent = 1075000
pop_1 = 2200
pop_2 = 8603000
pop_3 = 1720600
time_point_1 = 154600
time_point_2 = 158000
time_point_3 = 200000

# %%
theata_recent = 2 * pop_recent
time_ne_1 = time_point_1/pop_recent
time_ne_2 = time_point_2/pop_recent
time_ne_3 = time_point_3/pop_recent
relative_size_1 = pop_1/pop_recent
relative_size_2 = pop_2/pop_recent
relative_size_3 = pop_3/pop_recent

# !.././bin/blockbuster_simulator -n 20 -t {theata_recent} -p {time_ne_1},{time_ne_2},{time_ne_3},{relative_size_1},{relative_size_2},{relative_size_3} -o example_sfs.blk -f 1 -e 0
# Out:
# n_samples: 20
# theta: 2150000.000000
# oriented: 1
# seed: -1
# outfile: example_sfs.blk
# noised: 0
# parameters: 0.143814 0.146977 0.186047 0.002047 8.002791 1.600558
# Temps d'exécution : 0.0005300000 secondes
